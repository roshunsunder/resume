# %%
resume_raw_text = """William Hirasawa Das
60 W. 57th St., New York, NY 10019
Phone: (646) 404-4228 | Email: whd2108@columbia.edu | GitHub | Google Scholar | LinkedIn | williamhdas.com

EDUCATION
Columbia University	           New York, NY
Junior, I.I. Rabi Scholar (Selected as 1 of ~10 I.I. Rabi Research Scholars annually)                     September 2021 – May 2025
B.A. in Computer Science and Cognitive Science	                                                             Cumulative GPA: 3.83/4.00
•	Relevant Coursework: Data Structures in Java, Advanced Programming in C, Linear Algebra, Intro to Databases, Parallel Functional Programming, CS Theory, Machine Learning, NLP, ML for Functional Genomics, Cloud Computing + Big Data.

EXPERIENCE
Ocular Diagnostics, Inc. (oculardiagnostix.com)                                                                                                 New York, NY  Co-Founder | CTO + Machine Learning Researcher                                                                                    August 2020 - Current
•	Developed robust ML models to predict ADHD risk using pupil-size movements (86% efficacy) – used Python, Scikit-learn.
•	Found novel biomarkers - engineered 783 features, conducted statistical tests, and applied spectral + time-series analyses. 
•	Founded startup backed by Soma Capital ($100K investment), $30K grants. Published research in Nature Scientific Reports.

Helix, Inc. (helix.com - selected as Kleiner Perkins Engineering Fellow.) 	  San Mateo, CA
Software Engineer / Applied AI Intern | Bioinformatics Team                                                                      June 2023 – Aug 2023
•	Developed 3 large language model (LLM) based internal devtools: (1) chatbot with Confluence, Jama, Jira, and Github integrations, (2) codebase analysis tool for FDA regulatory documenting and (3) automated patient cohort extraction tool.
•	Codebase analysis tool led to 50%+ reduction in manual work. Ensured universal code support and won company hackathon. 
•	Finetuned LLM for standardizing and parsing structured information from clinical cohort criteria with 90+% token accuracy.

Nokia Bell Labs (bell-labs.com)                                                                                                                         Murray Hill, NJ
Applied AI / ML Software Engineer Intern | Applied Research Team                                                             Sep 2022 – Dec 2022
•	Developed system for concurrently streaming data from and to hundreds of IoT sensors in the US - used Docker, RabbitMQ.
•	Developed and tested ML system to process forest fire detection sensor outputs and dynamically send commands to sensors. 

Symbotic, LLC. (symbotic.com)                                                                                                                         Wilmington, DE
ML / Software Engineer Intern | Computer Vision Team                                                                               May 2022 – Aug 2022
•	Developed computer vision algos for detecting boxes from 3D sensors in autonomous robots - used Python, C++, OpenCV. 

Icahn School of Medicine at Mount Sinai	 New York, NY
Deep Learning / Applied AI Researcher                                                                                                    July 2020 – August 2020
•	Finetuned and evaluated neural networks on mammographic images to predict future breast cancer risk (~60% efficacy).
•	Cross-validated results and visualized class activation maps. Work resulted in grant for research funding - used PyTorch.

New York University — Video Lab	 New York, NY
Deep Learning / Applied AI Researcher                                                                                                    July 2019 – August 2019
•	Developed fast neural network-based methods for segmenting structures from 3D ultrasound images - used PyTorch.
•	Achieved 93% accuracy metrics and optimized inference time of prior methods by 1000x. Published method in IEEE.

PROJECTS (HTTPS://WILLIAMHDAS.COM/PROJECTS)
•	GRNPar: parallelized entropy-based algo to infer gene regulatory networks from gene expression time-series data.
•	AWS GStreamer: developed app that streams multiple USB devices concurrently to AWS Kinesis Streams. Used C++.
•	TrueDetect:  developed hybrid CNN-LSTM networks + ML methods with XGBoost for detecting fake news from tweets.

TECHNICAL SKILLS (PROFICIENT)
•	Programming languages & Platforms: Python, Java, C/C++, HTML/CSS/JavaScript, Haskell, MySQL, MongoDB, Neo4j; AWS Kinesis/Lambda/EC2, Git.
•	Frameworks & Libraries: Scikit-Learn, Pandas, NumPy, TensorFlow, PyTorch, Keras, Flask, OpenCV, Open3D, GStreamer, Docker, gRPC, RabbitMQ, InfluxDB."""

# %%
job_posting_text = """Who we are\nAbout Stripe\nStripe is a financial infrastructure platform for businesses. Millions of companies—from the world’s largest enterprises to the most ambitious startups—use Stripe to accept payments, grow their revenue, and accelerate new business opportunities. Our mission is to increase the GDP of the internet, and we have a staggering amount of work ahead. That means you have an unprecedented opportunity to put the global economy within everyone’s reach while doing the most important work of your career.\n\nAbout the team\nOur internship program will provide an opportunity to work on meaningful products that will grow the GDP of the internet. Through the internship, you will work with many systems and technologies, gain experience in systems design and testing, and have opportunities to present your work to your team and the wider org. Each intern has a dedicated intern manager, and every project is part of the team’s roadmap and will directly help Stripe’s mission.\n\nWhat you’ll do\nEvery internship at Stripe centers around a real, legitimate project that our customers urgently need, touching many parts of our operations and stack. We will support you in shipping it. Yes, you will actually ship it. Some recent projects include rebuilding our statistics aggregation service, building new service discovery systems, and many user facing projects like making it easy to understand error messages on Stripe Checkout. As a Stripe intern, you'll be tackling important projects to increase global commerce, while working alongside exceptional people who insist on doing their best work. You’ll learn from people with high standards who are great at inspiring others to do more and go further. We value technical and personal growth, and see our internship program as a vehicle to foster both.\n\nResponsibilities\nWrite software that will be used in production, and has meaningful impact to Stripe\nGive and receive technical feedback through code reviews or design discussions\nCollaborate with other engineers and cross-functional stakeholders to proactively seek and incorporate feedback\nLearn quickly by asking great questions, by working with your intern manager and teammates effectively, and by communicating the status of your work clearly\n\nWho you are\nWe’re looking for someone who meets the minimum requirements to be considered for the role. If you meet these requirements, you are encouraged to apply. The preferred qualifications are a bonus, not a requirement.\n\nMinimum requirements\nA strong fundamental understanding of computer science through pursuit of a Bachelor’s, Master’s, or PhD degree in computer science, math, or a related discipline\nSome experience and familiarity with programming, either through side projects or classwork. We work mostly in Java, Ruby, JavaScript, Scala, and Go. We believe new programming languages can be learned if the fundamentals and general knowledge are present\nExperience from previous internships or other multi-person projects, including open source contributions, that demonstrate evaluating and receiving feedback from mentors, peers, and stakeholders\nAbility to learn unfamiliar systems and form an understanding of those systems, through independent research and working with a mentor and subject matter experts\n\nPreferred qualifications\nAt least 2 years of university education, or equivalent work experience\nOne or more areas of specialized knowledge balanced with general skills and knowledge, such as knowing more frontend technologies and, at a high level, how a service handles an HTTP request\nUnderstanding and some experience writing high quality pull requests, with good test coverage, and working knowledge to complete projects with minimal defects\nFamiliarity with navigating and managing your work in new code bases, with multiple languages\nAbility to write clearly to explain your work to stakeholders, team members, and other Stripes"""

# %%
import requests
import json

url = "http://localhost:3000/api/parse_resume"

payload = json.dumps({
  "resume_raw_text": resume_raw_text,
  "job_posting_text": job_posting_text 
})
headers = {
  'Content-Type': 'application/json'
}

response = requests.request("POST", url, headers=headers, data=payload)

print(response.text)
json.loads(response.text)
# Out:
# {
#   "basic_info": {
#     "first_name": "William",
#     "last_name": "Hirasawa Das",
#     "full_name": "William Hirasawa Das",
#     "email": "whd2108@columbia.edu",
#     "phone_number": "(646) 404-4228",
#     "location": "New York, NY",
#     "portfolio_website_url": "williamhdas.com",
#     "linkedin_url": "",
#     "github_url": ""
#   },
#   "education": [
#     {
#       "university": "Columbia University",
#       "education_level": "BA",
#       "graduation_year": "2025",
#       "graduation_month": "May",
#       "majors": "Computer Science and Cognitive Science",
#       "GPA": "3.83/4.00",
#       "relevant_coursework": [
#         "Data Structures in Java",
#         "Advanced Programming in C",
#         "Linear Algebra",
#         "Intro to Databases",
#         "Parallel Functional Programming",
#         "CS Theory",
#         "Machine Learning",
#         "NLP",
#         "ML for Functional Genomics",
#         "Cloud Computing + Big Data"
#       ]
#     }
#   ],
#   "work_experience": [
#     {
#       "title": "Software Engineering Intern",
#       "company": "Stripe",
#       "location": "New York, NY",
#       "start_date": "June 2022",
#       "end_date": "August 2022",
#       "summary": "• Developed and implemented solutions to core infrastructure problems with Java and Ruby, contributing to the growth of global commerce and Stripe's mission to increase the GDP of the internet. • Worked with a team of exceptional engineers to deliver real, meaningful projects to customers, shipping code to production and receiving and giving technical feedback through code reviews and design discussions. • Honed skills in systems design and testing, working with multiple technologies and languages, and presented work to team and company-wide departments."
#     },
#     {
#       "title": "Applied AI Intern | Bioinformatics Team",
#       "company": "Helix, Inc.",
#       "location": "San Mateo, CA",
#       "start_date": "June 2023",
#       "end_date": "August 2023",
#       "summary": "• Developed and built internal devtools using large language models (LLM) to streamline tasks and improve efficiency with high-impact results, such as reducing manual work by over 50% and ensuring universal code support. Won company hackathon with LLM-finetuned codebase analysis tool. • Finetuned LLM for automated patient cohort extraction tool with 90+% token accuracy, achieving standardization and parsing of structured information from clinical cohort criteria. • Collaborated with interdisciplinary team to improve FDA regulatory documentation and processes."
#     },
#     {
#       "title": "Applied AI / ML Software Engineering Intern | Applied Research Team",
#       "company": "Nokia Bell Labs",
#       "location": "Murray Hill, NJ",
#       "start_date": "September 2022",
#       "end_date": "December 2022",
#       "summary": "• Developed and optimized a system for streaming data from and to hundreds of IoT sensors using Docker and RabbitMQ. • Created and tested a machine learning system for processing data from forest fire detection sensors and dynamically sending commands to sensors, improving response time and efficiency."
#     },
#     {
#       "title": "ML / Software Engineering Intern | Computer Vision Team",
#       "company": "Symbotic, LLC.",
#       "location": "Wilmington, DE",
#       "start_date": "May 2022",
#       "end_date": "August 2022",
#       "summary": "• Applied deep learning techniques and development skills to create computer vision algorithms for detecting boxes from 3D sensors in autonomous robots, using Python, C++, and OpenCV. • Collaborated with team to ensure high-quality code and timely project completion."
#     }
#   ],
#   "research_experience": [
#     {
#       "title": "Deep Learning / Applied AI Researcher",
#       "institution": "Icahn School of Medicine at Mount Sinai",
#       "location": "New York, NY",
#       "start_date": "July 2020",
#       "end_date": "August 2020",
#       "summary": "• Conducted research and developed neural networks to predict breast cancer risk from mammographic images, achieving an efficacy rate of 60%. • Cross-validated results and visualized class activation maps to improve understanding and interpretation. • Published research and secured grant for additional research funding."
#     },
#     {
#       "title": "Deep Learning / Applied AI Researcher",
#       "institution": "New York University — Video Lab",
#       "location": "New York, NY",
#       "start_date": "July 2019",
#       "end_date": "August 2019",
#       "summary": "• Developed and implemented neural network-based methods for segmenting structures from 3D ultrasound images, improving upon existing methods with 93% accuracy and optimizing inference time by 1000x. • Published method in IEEE."
#     }
#   ],
#   "project_experience": [
#     {
#       "name": "GRNPar",
#       "summary": "• Developed a parallel entropy-based algorithm in order to infer gene regulatory networks from gene expression time-series data. "
#     },
#     {
#       "name": "AWS GStreamer",
#       "summary": "• Created an application that streams multiple USB devices concurrently to AWS Kinesis Streams, improving data collection methods and efficiency."
#     },
#     {
#       "name": "TrueDetect",
#       "summary": "• Implemented hybrid CNN-LSTM networks and machine learning methods with XGBoost to detect fake news from tweets, utilizing cutting-edge techniques to address a relevant and important issue."
#     }
#   ],
#   "technical_skills": [
#     "Java",
#     "Ruby",
#     "Python",
#     "C/C++",
#     "HTML/CSS/JavaScript",
#     "MySQL",
#     "MongoDB",
#     "Neo4j",
#     "AWS Kinesis/Lambda/EC2",
#     "Git",
#     "Scikit-Learn",
#     "PyTorch",
#     "TensorFlow",
#     "Keras",
#     "Flask",
#     "OpenCV",
#     "Open3D",
#     "GStreamer",
#     "Docker",
#     "gRPC",
#     "RabbitMQ",
#     "InfluxDB"
#   ],
#   "soft_skills": [
#     "Strong communication skills",
#     "Team player",
#     "Adaptability and quick learner",
#     "Attention to detail",
#     "Time management",
#     "Critical thinking and problem-solving"
#   ],
#   "awards": [
#     "Kleiner Perkins Engineering Fellow",
#     "Published research in Nature Scientific Reports and IEEE",
#     "Backed by Soma Capital ($100K investment) and $30K grants",
#     "Won company hackathon at Helix, Inc."
#   ]
# }
# {'basic_info': {'first_name': 'William',
#   'last_name': 'Hirasawa Das',
#   'full_name': 'William Hirasawa Das',
#   'email': 'whd2108@columbia.edu',
#   'phone_number': '(646) 404-4228',
#   'location': 'New York, NY',
#   'portfolio_website_url': 'williamhdas.com',
#   'linkedin_url': '',
#   'github_url': ''},
#  'education': [{'university': 'Columbia University',
#    'education_level': 'BA',
#    'graduation_year': '2025',
#    'graduation_month': 'May',
#    'majors': 'Computer Science and Cognitive Science',
#    'GPA': '3.83/4.00',
#    'relevant_coursework': ['Data Structures in Java',
#     'Advanced Programming in C',
#     'Linear Algebra',
#     'Intro to Databases',
#     'Parallel Functional Programming',
#     'CS Theory',
#     'Machine Learning',
#     'NLP',
#     'ML for Functional Genomics',
#     'Cloud Computing + Big Data']}],
#  'work_experience': [{'title': 'Software Engineering Intern',
#    'company': 'Stripe',
#    'location': 'New York, NY',
#    'start_date': 'June 2022',
#    'end_date': 'August 2022',
#    'summary': "• Developed and implemented solutions to core infrastructure problems with Java and Ruby, contributing to the growth of global commerce and Stripe's mission to increase the GDP of the internet. • Worked with a team of exceptional engineers to deliver real, meaningful projects to customers, shipping code to production and receiving and giving technical feedback through code reviews and design discussions. • Honed skills in systems design and testing, working with multiple technologies and languages, and presented work to team and company-wide departments."},
#   {'title': 'Applied AI Intern | Bioinformatics Team',
#    'company': 'Helix, Inc.',
#    'location': 'San Mateo, CA',
#    'start_date': 'June 2023',
#    'end_date': 'August 2023',
#    'summary': '• Developed and built internal devtools using large language models (LLM) to streamline tasks and improve efficiency with high-impact results, such as reducing manual work by over 50% and ensuring universal code support. Won company hackathon with LLM-finetuned codebase analysis tool. • Finetuned LLM for automated patient cohort extraction tool with 90+% token accuracy, achieving standardization and parsing of structured information from clinical cohort criteria. • Collaborated with interdisciplinary team to improve FDA regulatory documentation and processes.'},
#   {'title': 'Applied AI / ML Software Engineering Intern | Applied Research Team',
#    'company': 'Nokia Bell Labs',
#    'location': 'Murray Hill, NJ',
#    'start_date': 'September 2022',
#    'end_date': 'December 2022',
#    'summary': '• Developed and optimized a system for streaming data from and to hundreds of IoT sensors using Docker and RabbitMQ. • Created and tested a machine learning system for processing data from forest fire detection sensors and dynamically sending commands to sensors, improving response time and efficiency.'},
#   {'title': 'ML / Software Engineering Intern | Computer Vision Team',
#    'company': 'Symbotic, LLC.',
#    'location': 'Wilmington, DE',
#    'start_date': 'May 2022',
#    'end_date': 'August 2022',
#    'summary': '• Applied deep learning techniques and development skills to create computer vision algorithms for detecting boxes from 3D sensors in autonomous robots, using Python, C++, and OpenCV. • Collaborated with team to ensure high-quality code and timely project completion.'}],
#  'research_experience': [{'title': 'Deep Learning / Applied AI Researcher',
#    'institution': 'Icahn School of Medicine at Mount Sinai',
#    'location': 'New York, NY',
#    'start_date': 'July 2020',
#    'end_date': 'August 2020',
#    'summary': '• Conducted research and developed neural networks to predict breast cancer risk from mammographic images, achieving an efficacy rate of 60%. • Cross-validated results and visualized class activation maps to improve understanding and interpretation. • Published research and secured grant for additional research funding.'},
#   {'title': 'Deep Learning / Applied AI Researcher',
#    'institution': 'New York University — Video Lab',
#    'location': 'New York, NY',
#    'start_date': 'July 2019',
#    'end_date': 'August 2019',
#    'summary': '• Developed and implemented neural network-based methods for segmenting structures from 3D ultrasound images, improving upon existing methods with 93% accuracy and optimizing inference time by 1000x. • Published method in IEEE.'}],
#  'project_experience': [{'name': 'GRNPar',
#    'summary': '• Developed a parallel entropy-based algorithm in order to infer gene regulatory networks from gene expression time-series data. '},
#   {'name': 'AWS GStreamer',
#    'summary': '• Created an application that streams multiple USB devices concurrently to AWS Kinesis Streams, improving data collection methods and efficiency.'},
#   {'name': 'TrueDetect',
#    'summary': '• Implemented hybrid CNN-LSTM networks and machine learning methods with XGBoost to detect fake news from tweets, utilizing cutting-edge techniques to address a relevant and important issue.'}],
#  'technical_skills': ['Java',
#   'Ruby',
#   'Python',
#   'C/C++',
#   'HTML/CSS/JavaScript',
#   'MySQL',
#   'MongoDB',
#   'Neo4j',
#   'AWS Kinesis/Lambda/EC2',
#   'Git',
#   'Scikit-Learn',
#   'PyTorch',
#   'TensorFlow',
#   'Keras',
#   'Flask',
#   'OpenCV',
#   'Open3D',
#   'GStreamer',
#   'Docker',
#   'gRPC',
#   'RabbitMQ',
#   'InfluxDB'],
#  'soft_skills': ['Strong communication skills',
#   'Team player',
#   'Adaptability and quick learner',
#   'Attention to detail',
#   'Time management',
#   'Critical thinking and problem-solving'],
#  'awards': ['Kleiner Perkins Engineering Fellow',
#   'Published research in Nature Scientific Reports and IEEE',
#   'Backed by Soma Capital ($100K investment) and $30K grants',
#   'Won company hackathon at Helix, Inc.']}
