# %%
from langchain.embeddings.openai import OpenAIEmbeddings
from langchain.vectorstores import Chroma
from langchain.text_splitter import CharacterTextSplitter, RecursiveCharacterTextSplitter
from langchain import OpenAI, VectorDBQA
from langchain.document_loaders import DirectoryLoader
import os
import nltk

# %%
os.environ['OPENAI_API_KEY'] = "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"

# %%
loader = DirectoryLoader('./datadir', glob='**/*.txt')
documents = loader.load()
text_splitter = RecursiveCharacterTextSplitter(
    # Set a really small chunk size, just to show.
    chunk_size = 1000,
    chunk_overlap  = 0,
    length_function = len,
)

# %%
texts = text_splitter.split_documents(documents)
embeddings = OpenAIEmbeddings(openai_api_key = os.environ['OPENAI_API_KEY'])

# %%
texts
# Out:
# [Document(page_content='Question CSP CAIQ Answer CSP Implementation Description (Optional/Recommended)\n\n0 Are audit and assurance policies, procedures, and standards established,\n\ndocumented, approved, communicated, applied, evaluated, and maintained? Yes Adobe’s security organization is responsible for the coordination of development and maintenance of corporate policies and standards that impact information security at Adobe. These include audit and assurance related standards such as the Technology Risk Management Standard and the Information Security Management Standard. The policies and standards are reviewed by relevant stakeholders and approved by document owners at least annually. The policies and standards are made available to all Adobe employees on a centralized Adobe intranet site. Additionally, the policies and standards are referenced in annual security and awareness training.\n\nAdobe has been annually evaluated by independent auditors against various certification
# ...

# %%
docsearch = Chroma.from_documents(texts, embeddings, persist_directory="db/")
# Out:
# Using embedded DuckDB with persistence: data will be stored in: db/

# %%
from langchain.chains import ChatVectorDBQAChain
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# Cell In[11], line 1
# ----> 1 from langchain.chains import ChatVectorDBQAChain
#
# ImportError: cannot import name 'ChatVectorDBQAChain' from 'langchain.chains' (/Users/roshun/Documents/poc/flask-server/virtualenv/lib/python3.10/site-packages/langchain/chains/__init__.py)
